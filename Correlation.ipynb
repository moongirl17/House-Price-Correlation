# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import io

# %%
df=pd.read_csv('/content/kc_house_data.csv')

# %% [markdown]
# # **Data Frame Before Cleaning**

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# # **Data Cleaning**

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21608    False
# 21609    False
# 21610    False
# 21611    False
# 21612    False
# Length: 21613, dtype: bool

# %%
df['date']=pd.to_datetime(df.date).dt.strftime('%d/%m/%Y')
df.head(6)
# Out:
#            id        date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  13/10/2014   221900.0         3       1.00         1180
# 1  6414100192  09/12/2014   538000.0         3       2.25         2570
# 2  5631500400  25/02/2015   180000.0         2       1.00          770
# 3  2487200875  09/12/2014   604000.0         4       3.00         1960
# 4  1954400510  18/02/2015   510000.0         3       2.00         1680
# 5  7237550310  12/05/2014  1225000.0         4       4.50         5420
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (21613, 21)

# %% [markdown]
# # **Data Exploration**

# %%
df2 = df.drop(['id', 'zipcode', 'date'], 1)

df2.head(5)
# Out:
# <ipython-input-12-87bc7ff6a51c>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df2 = df.drop(['id', 'zipcode', 'date'], 1)
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          21613 non-null  float64
#  1   bedrooms       21613 non-null  int64
#  2   bathrooms      21613 non-null  float64
#  3   sqft_living    21613 non-null  int64
#  4   sqft_lot       21613 non-null  int64
#  5   floors         21613 non-null  float64
#  6   waterfront     21613 non-null  int64
#  7   view           21613 non-null  int64
#  8   condition      21613 non-null  int64
#  9   grade          21613 non-null  int64
#  10  sqft_above     21613 non-null  int64
#  11  sqft_basement  21613 non-null  int64
#  12  yr_built       21613 non-null  int64
#  13  yr_renovated   21613 non-null  int64
#  14  lat            21613 non-null  float64
#  15  long           21613 non-null  float64
#  16  sqft_living15  21613 non-null  int64
# ...

# %%
df2.describe()
# Out:
#               price      bedrooms  ...  sqft_living15     sqft_lot15
# count  2.161300e+04  21613.000000  ...   21613.000000   21613.000000
# mean   5.400881e+05      3.370842  ...    1986.552492   12768.455652
# std    3.671272e+05      0.930062  ...     685.391304   27304.179631
# min    7.500000e+04      0.000000  ...     399.000000     651.000000
# 25%    3.219500e+05      3.000000  ...    1490.000000    5100.000000
# 50%    4.500000e+05      3.000000  ...    1840.000000    7620.000000
# 75%    6.450000e+05      4.000000  ...    2360.000000   10083.000000
# max    7.700000e+06     33.000000  ...    6210.000000  871200.000000
#
# [8 rows x 18 columns]

# %%
df.sort_values('price').head(5)
# Out:
#                id        date    price  ...     long  sqft_living15  sqft_lot15
# 1149   3421079032  17/02/2015  75000.0  ... -121.906           1160       42882
# 15293    40000362  06/05/2014  78000.0  ... -122.280           1700       10387
# 465    8658300340  23/05/2014  80000.0  ... -121.909           1200        7500
# 16198  3028200080  24/03/2015  81000.0  ... -122.315            860        9000
# 8274   3883800011  05/11/2014  82000.0  ... -122.341           1140       11250
#
# [5 rows x 21 columns]

# %%
df2['price'].value_counts(ascending = False)
# Out:
# 450000.0    172
# 350000.0    172
# 550000.0    159
# 500000.0    152
# 425000.0    150
#            ...
# 641500.0      1
# 575950.0      1
# 674250.0      1
# 608700.0      1
# 884744.0      1
# Name: price, Length: 4028, dtype: int64

# %%
df2.sort_values('price', ascending = False).head(5)
# Out:
#           price  bedrooms  bathrooms  ...     long  sqft_living15  sqft_lot15
# 7252  7700000.0         6       8.00  ... -122.323           3940        8800
# 3914  7062500.0         5       4.50  ... -122.214           3930       25449
# 9254  6885000.0         6       7.75  ... -122.240           4540       42730
# 4411  5570000.0         5       5.75  ... -122.233           3560       24345
# 1448  5350000.0         5       5.00  ... -122.220           4600       21750
#
# [5 rows x 18 columns]

# %%
df2['bedrooms'].value_counts(ascending = False)
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 8       13
# 0       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
df2['bathrooms'].value_counts(ascending = False)
# Out:
# 2.50    5380
# 1.00    3852
# 1.75    3048
# 2.25    2047
# 2.00    1930
# 1.50    1446
# 2.75    1185
# 3.00     753
# 3.50     731
# 3.25     589
# 3.75     155
# 4.00     136
# 4.50     100
# 4.25      79
# 0.75      72
# 4.75      23
# 5.00      21
# 5.25      13
# 0.00      10
# 5.50      10
# 1.25       9
# 6.00       6
# 0.50       4
# 5.75       4
# 8.00       2
# 6.25       2
# 6.50       2
# 6.75       2
# 7.50       1
# 7.75       1
# Name: bathrooms, dtype: int64

# %%
df2['sqft_living'].value_counts(ascending = False)
# Out:
# 1300    138
# 1400    135
# 1440    133
# 1010    129
# 1660    129
#        ...
# 3001      1
# 4970      1
# 2905      1
# 2793      1
# 1975      1
# Name: sqft_living, Length: 1038, dtype: int64

# %%
df2['sqft_lot'].value_counts(ascending = False)
# Out:
# 5000     358
# 6000     290
# 4000     251
# 7200     220
# 4800     120
#         ...
# 38884      1
# 17313      1
# 35752      1
# 937        1
# 14321      1
# Name: sqft_lot, Length: 9782, dtype: int64

# %%
df2['yr_built'].value_counts(ascending = False)
# Out:
# 2014    559
# 2006    454
# 2005    450
# 2004    433
# 2003    422
#        ...
# 1933     30
# 1901     29
# 1902     27
# 1935     24
# 1934     21
# Name: yr_built, Length: 116, dtype: int64

# %%
df2['yr_renovated'].value_counts(ascending = False)
# Out:
# 0       20699
# 2014       91
# 2013       37
# 2003       36
# 2000       35
#         ...
# 1934        1
# 1959        1
# 1951        1
# 1948        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
df['floors'].value_counts(ascending = False)
# Out:
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: floors, dtype: int64

# %% [markdown]
# ### **Median, Mean**

# %%
df2.median()
# Out:
# price            450000.0000
# bedrooms              3.0000
# bathrooms             2.2500
# sqft_living        1910.0000
# sqft_lot           7618.0000
# floors                1.5000
# waterfront            0.0000
# view                  0.0000
# condition             3.0000
# grade                 7.0000
# sqft_above         1560.0000
# sqft_basement         0.0000
# yr_built           1975.0000
# yr_renovated          0.0000
# lat                  47.5718
# long               -122.2300
# sqft_living15      1840.0000
# sqft_lot15         7620.0000
# dtype: float64

# %%
df2.mean()
# Out:
# price            540088.141767
# bedrooms              3.370842
# bathrooms             2.114757
# sqft_living        2079.899736
# sqft_lot          15106.967566
# floors                1.494309
# waterfront            0.007542
# view                  0.234303
# condition             3.409430
# grade                 7.656873
# sqft_above         1788.390691
# sqft_basement       291.509045
# yr_built           1971.005136
# yr_renovated         84.402258
# lat                  47.560053
# long               -122.213896
# sqft_living15      1986.552492
# sqft_lot15        12768.455652
# dtype: float64

# %% [markdown]
# # **Data Visualization**

# %% [markdown]
# ### **Plot Scatter**

# %%
# plot the relationship between “sqft_lot15” and ”price”
df2.plot.scatter('bathrooms', 'price')

# %%
# plot the relationship between “sqft_lot15” and ”price”
df2.plot.scatter('bedrooms', 'price')

# %%
# plot the relationship between “sqft_living” and ”price”
df2.plot.scatter('sqft_living', 'price')

# %%
# plot the relationship between “sqft_lot15” and ”price”
df2.plot.scatter('sqft_lot', 'price')

# %%
# plot the relationship between “sqft_lot15” and ”price”
df2.plot.scatter('floors', 'price')

# %%
# plot the relationship between “sqft_lot15” and ”price”
df2.plot.scatter('waterfront', 'price')

# %%
# plot the relationship between “sqft_lot15” and ”price”
df2.plot.scatter('view', 'price')

# %%
# plot the relationship between “sqft_lot15” and ”price”
df2.plot.scatter('condition', 'price')

# %%
# plot the relationship between “grade” and ”price”
df2.plot.scatter('grade', 'price')

# %%
# plot the relationship between “sqft_above” and ”price”
df2.plot.scatter('sqft_above', 'price')

# %%
# plot the relationship between “sqft_lot15” and ”price”
df2.plot.scatter('sqft_basement', 'price')

# %%
# plot the relationship between “sqft_lot15” and ”price”
df2.plot.scatter('yr_built', 'price')

# %%
# plot the relationship between “sqft_lot15” and ”price”
df2.plot.scatter('yr_renovated', 'price')

# %%
# plot the relationship between “sqft_lot15” and ”price”
df2.plot.scatter('lat', 'price')

# %%
# plot the relationship between “sqft_lot15” and ”price”
df2.plot.scatter('long', 'price')

# %%
# plot the relationship between “sqft_lot15” and ”price”
df2.plot.scatter('sqft_living15', 'price')

# %%
# plot the relationship between “sqft_lot15” and ”price”
df2.plot.scatter('sqft_lot15', 'price')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# ### **Histogram**

# %%
df2.hist(bins=100, figsize=(20, 15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1a67d48490>,
# ...
#       dtype=object)

# %% [markdown]
# ### **Boxplot and pairplot of bedroom, bathroom, floor**

# %%
#boxplot the relationship between “sqft_lot15” and ”price”
sns.boxplot(x = 'bedrooms', y = 'price', data = df2)
plt.show()

# %%
#boxplot the relationship between “sqft_lot15” and ”price”
sns.boxplot(x = 'bathrooms', y = 'price', data = df2)
plt.show()

# %%
#boxplot the relationship between “sqft_lot15” and ”price”
sns.boxplot(x = 'floors', y = 'price', data = df2)
plt.show()

# %%
sns.set(style="ticks", color_codes=True)
sns.pairplot(df2,vars = ['bedrooms', 'bathrooms','floors'],
hue="price")
plt.show()

# %% [markdown]
# ### **Boxplot and pairplot of View, Condition, Grade**

# %%
#boxplot the relationship between “sqft_lot15” and ”price”
sns.boxplot(x = 'view', y = 'price', data = df2)
plt.show()

# %%
#boxplot the relationship between “sqft_lot15” and ”price”
sns.boxplot(x = 'condition', y = 'price', data = df2)
plt.show()

# %%
#boxplot the relationship between “sqft_lot15” and ”price”
sns.boxplot(x = 'grade', y = 'price', data = df2)
plt.show()

# %%
sns.set(style="ticks", color_codes=True)
sns.pairplot(df2,vars = ['view','condition', 'grade'],
hue="price")
plt.show()

# %% [markdown]
# # **Correlation**

# %%
corr = df2.corr(method='pearson')
corr
# Out:
#                   price  bedrooms  ...  sqft_living15  sqft_lot15
# price          1.000000  0.308350  ...       0.585379    0.082447
# bedrooms       0.308350  1.000000  ...       0.391638    0.029244
# bathrooms      0.525138  0.515884  ...       0.568634    0.087175
# sqft_living    0.702035  0.576671  ...       0.756420    0.183286
# sqft_lot       0.089661  0.031703  ...       0.144608    0.718557
# floors         0.256794  0.175429  ...       0.279885   -0.011269
# waterfront     0.266369 -0.006582  ...       0.086463    0.030703
# view           0.397293  0.079532  ...       0.280439    0.072575
# condition      0.036362  0.028472  ...      -0.092824   -0.003406
# grade          0.667434  0.356967  ...       0.713202    0.119248
# sqft_above     0.605567  0.477600  ...       0.731870    0.194050
# sqft_basement  0.323816  0.303093  ...       0.200355    0.017276
# yr_built       0.054012  0.154178  ...       0.326229    0.070958
# ...

# %%
def resizeplot(l,a):
    plt.figure(figsize=(l,a))
    
x = df.iloc[:, 1:]

# %%
resizeplot(16,7)
corr = x.corr()
sns.heatmap(corr, annot=True)

# %%
corr['price'].sort_values(ascending = False)
# Out:
# price            1.000000
# sqft_living      0.702035
# grade            0.667434
# sqft_above       0.605567
# sqft_living15    0.585379
# bathrooms        0.525138
# view             0.397293
# sqft_basement    0.323816
# bedrooms         0.308350
# lat              0.307003
# waterfront       0.266369
# floors           0.256794
# yr_renovated     0.126434
# sqft_lot         0.089661
# sqft_lot15       0.082447
# yr_built         0.054012
# condition        0.036362
# long             0.021626
# zipcode         -0.053203
# Name: price, dtype: float64

# %% [markdown]
# ### **sqft_living** (Square footage of the apartments interior living space)

# %%
#FacetGrid of Price
sns.FacetGrid(df2,size=5).map(sns.distplot,"price").add_legend()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#FacetGrid of sqft_living
sns.FacetGrid(df2,size=5).map(sns.distplot,"sqft_living").add_legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Boxplot of price
sns.boxplot(x = "price",data = df2)
plt.show()

# %%
#Boxplot of sqft_living
sns.boxplot(x = "sqft_living", data = df2)
plt.show()

# %%
from scipy import stats
corr = stats.pearsonr(df2["price"], df2["sqft_living"])
print("p-value:\t", corr[1])
print("cor:\t\t", corr[0])
# Out:
# p-value:	 0.0
# cor:		 0.7020350546118002

# %% [markdown]
# ### **Grade** (An index from 1 to 13, where 1-3 falls short of building construction and design, 7 has an average level of construction and design, and 11-13 have a high quality level of construction and design)

# %%
#FacetGrid of Price
sns.FacetGrid(df2,size=5).map(sns.distplot,"price").add_legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#FacetGrid of grade
sns.FacetGrid(df2,size=5).map(sns.distplot,"grade").add_legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Boxplot of price
sns.boxplot(x = "price",data = df2)
plt.show()

# %%
#Boxplot of  grade
sns.boxplot(x = "grade",data = df2)
plt.show()

# %%
from scipy import stats
corr = stats.pearsonr(df2["price"], df2["grade"])
print("p-value:\t", corr[1])
print("cor:\t\t", corr[0])
# Out:
# p-value:	 0.0
# cor:		 0.6674342560202371

# %% [markdown]
# ### **sqft_above** (The square footage of the interior housing space that is above ground level)

# %%
#FacetGrid of Price
sns.FacetGrid(df2,size=5).map(sns.distplot,"price").add_legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#FacetGridof sqft_above
sns.FacetGrid(df2,size=5).map(sns.distplot,"sqft_above").add_legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Boxplot of price
sns.boxplot(x = "price",data = df2)
plt.show()

# %%
#Boxplot of sqft_above
sns.boxplot(x = "sqft_above",data = df2)
plt.show()

# %%
from scipy import stats
corr = stats.pearsonr(df2["price"], df2["sqft_above"])
print("p-value:\t", corr[1])
print("cor:\t\t", corr[0])
# Out:
# p-value:	 0.0
# cor:		 0.605567298356078

# %%
def round_sqft_above(df):
    df['sqft_above'] = df['grade'].map(lambda x: int(round(x)))
    return df
df = round_sqft_above(df)

# %%
def round_sqft_living(df):
    df['sqft_living'] = df['grade'].map(lambda x: int(round(x)))
    return df
df = round_sqft_living(df)

# %%
place = ['sqft_living', 'grade', 'sqft_above']

for feature in place:
    sns.boxplot(x = df[feature], y = df['price'])
    plt.title(f"Boxplot of {feature} vs. price")
    plt.ylabel("Price")
    plt.xlabel(f"{feature}")
    plt.show()

# %%
#plot (matrix scatterplot) of  qft_living, grade, sqft_above
sns.set(style="ticks", color_codes=True)
sns.pairplot(df2,vars = ['sqft_living', 'grade','sqft_above'],
hue="price")
plt.show()

# %%
label = ['sqft_living', 'grade','sqft_above']
jumlah = [0.702035, 0.667434,  0.605567]
plt.pie(jumlah, labels = label, autopct = "%1.1f%%")
plt.show()

# %%
df['price'] = df['price'].astype('int')
df['sqft_living'] = df['sqft_living'].astype('int')
df['grade'] = df['grade'].astype('int')
df['sqft_above'] = df['sqft_above'].astype('int')

# %%
df.describe()
# Out:
#                  id         price  ...  sqft_living15     sqft_lot15
# count  2.161300e+04  2.161300e+04  ...   21613.000000   21613.000000
# mean   4.580302e+09  5.400881e+05  ...    1986.552492   12768.455652
# std    2.876566e+09  3.671272e+05  ...     685.391304   27304.179631
# min    1.000102e+06  7.500000e+04  ...     399.000000     651.000000
# 25%    2.123049e+09  3.219500e+05  ...    1490.000000    5100.000000
# 50%    3.904930e+09  4.500000e+05  ...    1840.000000    7620.000000
# 75%    7.308900e+09  6.450000e+05  ...    2360.000000   10083.000000
# max    9.900000e+09  7.700000e+06  ...    6210.000000  871200.000000
#
# [8 rows x 20 columns]
